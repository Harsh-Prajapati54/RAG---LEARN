# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsh-Prajapati54/RAG---LEARN/blob/main/RAG_From_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RAG --  Retrival Augmentation Generations

# %% [markdown]
# In this repo i am going to Implement and learn an RAG system from scratch
#
# I am following the youtube tutorial from freecodecamp :- https://youtu.be/sVcwVQRHIc8?si=b90Qq9wGx75rkmpm
